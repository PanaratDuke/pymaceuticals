# %%
# %matplotlib notebook

# %%
#--Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
#--Study data files
mouse_metadata = "data/Mouse_metadata.csv"
study_results = "data/Study_results.csv"

# %%
#--Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata)
study_results = pd.read_csv(study_results)

# %%
# mouse_metadata.head()
mouse_metadata.count()
# Out:
# Mouse ID        249
# Drug Regimen    249
# Sex             249
# Age_months      249
# Weight (g)      249
# dtype: int64

# %%
# study_results.head()
study_results.count
# Out:
# <bound method DataFrame.count of      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0        b128          0           45.000000                 0
# 1        f932          0           45.000000                 0
# 2        g107          0           45.000000                 0
# 3        a457          0           45.000000                 0
# 4        c819          0           45.000000                 0
# ...       ...        ...                 ...               ...
# 1888     r944         45           41.581521                 2
# 1889     u364         45           31.023923                 3
# 1890     p438         45           61.433892                 1
# 1891     x773         45           58.634971                 4
# 1892     b879         45           72.555239                 2
#
# [1893 rows x 4 columns]>

# %%
combined_data = pd.merge(study_results,mouse_metadata, on='Mouse ID')

# %%
combined_data.columns
# Out:
# Index(['Mouse ID', 'Timepoint', 'Tumor Volume (mm3)', 'Metastatic Sites',
#        'Drug Regimen', 'Sex', 'Age_months', 'Weight (g)'],
#       dtype='object')

# %%
combined_data.head(100)
# Out:
#    Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0      b128          0           45.000000                 0    Capomulin
# 1      b128          5           45.651331                 0    Capomulin
# 2      b128         10           43.270852                 0    Capomulin
# 3      b128         15           43.784893                 0    Capomulin
# 4      b128         20           42.731552                 0    Capomulin
# ..      ...        ...                 ...               ...          ...
# 95     x930         25           53.726101                 0     Naftisol
# 96     o725          0           45.000000                 0     Naftisol
# 97     o725          5           46.889821                 0     Naftisol
# 98     o725         10           48.199452                 0     Naftisol
# 99     o725         15           50.015079                 1     Naftisol
#
#        Sex  Age_months  Weight (g)
# 0   Female           9          22
# 1   Female           9          22
# 2   Female           9          22
# 3   Female           9          22
# 4   Female           9          22
# ..     ...         ...         ...
# 95    Male          13          26
# 96    Male           4          26
# 97    Male           4          26
# 98    Male           4          26
# 99    Male           4          26
#
# [100 rows x 8 columns]

# %%
# #--Generate a summary statistics mean, median, variance, 
# #standard deviation, and SEM of the tumor volume for each regimen
# grouped_drug = combined_data.groupby('Mouse ID')['Tumor Volume (mm3)'].mean()

# grouped_drug.head()

# %%
#--Calculate mean 
mouse_df = combined_data[['Drug Regimen','Tumor Volume (mm3)']]
mouse_mean = mouse_df.groupby(["Drug Regimen"]).mean()
mouse_mean = mouse_mean.rename(columns={'Tumor Volume (mm3)':"Mean Tumor Volume"})
mouse_mean.head()
# df.rename(columns={"A": "a", "B": "c"})
# Out:
#               Mean Tumor Volume
# Drug Regimen
# Capomulin             40.675741
# Ceftamin              52.591172
# Infubinol             52.884795
# Ketapril              55.235638
# Naftisol              54.331565

# %%
#--Calculate median
mouse_median = mouse_df.groupby(["Drug Regimen"]).median()
mouse_median = mouse_median.rename(columns={'Tumor Volume (mm3)':"Median Tumor Volume"})
mouse_median.head()
# Out:
#               Median Tumor Volume
# Drug Regimen
# Capomulin               41.557809
# Ceftamin                51.776157
# Infubinol               51.820584
# Ketapril                53.698743
# Naftisol                52.509285

# %%
#--Combine mean and median
mouse_table = pd.merge(mouse_mean,mouse_median, on = 'Drug Regimen')
mouse_table.head()
# Out:
#               Mean Tumor Volume  Median Tumor Volume
# Drug Regimen
# Capomulin             40.675741            41.557809
# Ceftamin              52.591172            51.776157
# Infubinol             52.884795            51.820584
# Ketapril              55.235638            53.698743
# Naftisol              54.331565            52.509285

# %%
#--Calculate Variance
mouse_var = mouse_df.groupby(["Drug Regimen"]).var()
mouse_var = mouse_var.rename(columns={'Tumor Volume (mm3)':"Tumor Volume Variance"})
mouse_var.head()
# Out:
#               Tumor Volume Variance
# Drug Regimen
# Capomulin                 24.947764
# Ceftamin                  39.290177
# Infubinol                 43.128684
# Ketapril                  68.553577
# Naftisol                  66.173479

# %%
#--Combine mean, median with Variance
mouse_table = pd.merge(mouse_table,mouse_var, on = 'Drug Regimen')
mouse_table.head()
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479

# %%
#--Calculate Standard Deviation
mouse_std = mouse_df.groupby(["Drug Regimen"]).std()
mouse_std = mouse_std.rename(columns={'Tumor Volume (mm3)':"Tumor Volume Std. Dev."})
mouse_std.head()
# Out:
#               Tumor Volume Std. Dev.
# Drug Regimen
# Capomulin                   4.994774
# Ceftamin                    6.268188
# Infubinol                   6.567243
# Ketapril                    8.279709
# Naftisol                    8.134708

# %%
#--Combine mean, median, var with std. dev
mouse_table = pd.merge(mouse_table,mouse_std, on = 'Drug Regimen')
mouse_table.head()
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
#
#               Tumor Volume Std. Dev.
# Drug Regimen
# Capomulin                   4.994774
# Ceftamin                    6.268188
# Infubinol                   6.567243
# Ketapril                    8.279709
# Naftisol                    8.134708

# %%
#--Calculate std. err
mouse_sem = mouse_df.groupby(["Drug Regimen"]).sem()
mouse_sem = mouse_sem.rename(columns={'Tumor Volume (mm3)':"Tumor Volume Std. Err."})
mouse_sem.head()
# Out:
#               Tumor Volume Std. Err.
# Drug Regimen
# Capomulin                   0.329346
# Ceftamin                    0.469821
# Infubinol                   0.492236
# Ketapril                    0.603860
# Naftisol                    0.596466

# %% [markdown]
# ## Summary statistics Table 1

# %%
#--Combine mean, median, Variance
mouse_table = pd.merge(mouse_table,mouse_sem, on = 'Drug Regimen')
mouse_table.head()
# mouse_table.columns
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# Capomulin                   4.994774                0.329346
# Ceftamin                    6.268188                0.469821
# Infubinol                   6.567243                0.492236
# Ketapril                    8.279709                0.603860
# Naftisol                    8.134708                0.596466

# %% [markdown]
# ## Summary statisctics Table 2

# %%
# mouse_table.columns
mouse_table_2 = mouse_table.loc[:,['Mean Tumor Volume','Median Tumor Volume', 'Tumor Volume Variance',
       'Tumor Volume Std. Dev.', 'Tumor Volume Std. Err.']]
mouse_table_2=mouse_table_2.rename(columns={'Mean Tumor Volume':'Tumor Volume (mm3) mean',
                                            'Median Tumor Volume':"median",
                                           'Tumor Volume Variance':'var',
                                           'Tumor Volume Std. Dev.':'std', 
                                            'Tumor Volume Std. Err.':'sem'})
mouse_table_2.head()
# Out:
#               Tumor Volume (mm3) mean     median        var       std  \
# Drug Regimen
# Capomulin                   40.675741  41.557809  24.947764  4.994774
# Ceftamin                    52.591172  51.776157  39.290177  6.268188
# Infubinol                   52.884795  51.820584  43.128684  6.567243
# Ketapril                    55.235638  53.698743  68.553577  8.279709
# Naftisol                    54.331565  52.509285  66.173479  8.134708
#
#                    sem
# Drug Regimen
# Capomulin     0.329346
# Ceftamin      0.469821
# Infubinol     0.492236
# Ketapril      0.603860
# Naftisol      0.596466

# %% [markdown]
# ## Pandas Plots Bar Chart

# %%
#--Collect the data into variable 
panda_mouse_bar = combined_data['Drug Regimen'].value_counts()

#--Plot bar chart using Panda (number of data points for each treatment regimen) 
panda_mouse_bar.plot(kind='bar',facecolor='blue')

#--Add x and y label and show graph
plt.tight_layout()
plt.ylabel("Number of Data Points")
plt.xlabel("Drug Regimen")
plt.show()

# %% [markdown]
# ## MatPlotLib Plots Bar Chart

# %%
#--Assign x_axis and y_axis 
x = combined_data['Drug Regimen'].value_counts()
x_axis = np.arange(1,len(x)+1,1)
y_axis = x

#--Plot bar chart using pyplot (number of data points for each treatment regimen) 
plt.bar(x_axis,y_axis, color='b',align='center')

#--Place x_axis header
x_header = combined_data['Drug Regimen']
x_axis_header = x_header.unique()
x_axis_header
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, x_axis_header, rotation = "vertical")

#--Add x and y label and show graph
plt.ylabel("Number of Data Points")
plt.xlabel("Drug Regimen")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Pandas Plots Pie Chart

# %%
#-Showing the distribution of female VS male mice
#--Collect data
mouse_gender = mouse_metadata['Sex'].value_counts()
mouse_gender

#--Plot pie chart using pandas
mouse_gender.plot(kind='pie',autopct='%1.1f%%')
plt.title("Sex")
# Out:
# Text(0.5, 1.0, 'Sex')

# %% [markdown]
# ## MatPlotLib Plots Pie Chart

# %%
#-Showing the distribution of female VS male mice
#--Collect data
mouse_gender = mouse_metadata['Sex'].unique()
mouse_gender_df = mouse_metadata['Sex'].value_counts()

#--Plot pie chart using pyplots
plt.pie(
    mouse_gender_df,
    labels=mouse_gender,
    autopct='%1.1f%%'
    )
plt.title("Sex",loc = 'left')
##--How to use this
# fontdict : dict
# A dictionary controlling the appearance of the title text, the default fontdict is:

# {'fontsize': rcParams['axes.titlesize'],
#  'fontweight' : rcParams['axes.titleweight'],
#  'verticalalignment': 'baseline',
#  'horizontalalignment': loc}
# Out:
# Text(0.0, 1.0, 'Sex')

# %% [markdown]
# ## Quartiles, outliers and boxplots

# %%
#--Select dataframe to calculate
combined_data.head(30)
# Out:
#    Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0      b128          0           45.000000                 0    Capomulin
# 1      b128          5           45.651331                 0    Capomulin
# 2      b128         10           43.270852                 0    Capomulin
# 3      b128         15           43.784893                 0    Capomulin
# 4      b128         20           42.731552                 0    Capomulin
# 5      b128         25           43.262145                 1    Capomulin
# 6      b128         30           40.605335                 1    Capomulin
# 7      b128         35           37.967644                 1    Capomulin
# 8      b128         40           38.379726                 2    Capomulin
# 9      b128         45           38.982878                 2    Capomulin
# 10     f932          0           45.000000                 0     Ketapril
# 11     g107          0           45.000000                 0     Ketapril
# 12     g107          5           48.791665                 0     Ketapril
# 13     g107         10           53.435987                 0     Ketapril
# 14     g107         15           58.135545                 0     Ketapril
# 15     g107         20           62.706031                 0     Ketapril
# 16     g107         25           64.663626                 0     Ketapril
# 17     g107         30           69.160520                 0     Ketapril
# 18     g107         35           71.905117                 0     Ketapril
# 19     a457          0           45.000000                 0     Ketapril
# 20     a457          5           47.462891                 0     Ketapril
# 21     a457         10           49.783419                 0     Ketapril
# 22     c819          0           45.000000                 0     Ketapril
# 23     c819          5           45.769249                 1     Ketapril
# 24     c819         10           46.658395                 1     Ketapril
# 25     c819         15           48.370999                 1     Ketapril
# 26     c819         20           49.762415                 1     Ketapril
# 27     c819         25           51.828357                 1     Ketapril
# 28     c819         30           56.098998                 1     Ketapril
# 29     c819         35           57.729535                 1     Ketapril
#
#        Sex  Age_months  Weight (g)
# 0   Female           9          22
# 1   Female           9          22
# 2   Female           9          22
# 3   Female           9          22
# 4   Female           9          22
# 5   Female           9          22
# 6   Female           9          22
# 7   Female           9          22
# 8   Female           9          22
# 9   Female           9          22
# 10    Male          15          29
# 11  Female           2          29
# 12  Female           2          29
# 13  Female           2          29
# 14  Female           2          29
# 15  Female           2          29
# 16  Female           2          29
# 17  Female           2          29
# 18  Female           2          29
# 19  Female          11          30
# 20  Female          11          30
# 21  Female          11          30
# 22    Male          21          25
# 23    Male          21          25
# 24    Male          21          25
# 25    Male          21          25
# 26    Male          21          25
# 27    Male          21          25
# 28    Male          21          25
# 29    Male          21          25

# %%
# select_df = combined_data.loc[:,('Drug Regimen','Tumor Volume (mm3)','Mouse ID')]
# group_drug_df = select_df.groupby('Drug Regimen').mean()

# sort_tumor_mean_df = group_drug_df.sort_values('Tumor Volume (mm3)')
# sort_tumor_mean_df

# %%
#--Grouped data (Mouse ID and Drug Regimen) and create new dataframe
grouped_mouse_df = combined_data.groupby(['Drug Regimen','Mouse ID'],as_index=True).agg({'Tumor Volume (mm3)':'mean'
                                                                           }).rename(columns={'Tumor Volume (mm3)':'Tumor mean'})
#--Sort to find least mean value
sort_mean_df = grouped_mouse_df.sort_values('Tumor mean')
sort_mean_df.
# Out:
#   File "<ipython-input-82-a6e00d35e998>", line 6
#     sort_mean_df.
#                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Line Plots

# %%
#--Extract rows corresponding only to Capomulin
capomulin_df = combined_data.loc[(combined_data['Drug Regimen']=='Capomulin') 
                                 & (combined_data['Mouse ID']=='l509'),['Timepoint','Tumor Volume (mm3)']]
capomulin_df
# Out:
#       Timepoint  Tumor Volume (mm3)
# 1721          0           45.000000
# 1722          5           45.851193
# 1723         10           46.759074
# 1724         15           47.488599
# 1725         20           48.070452
# 1726         25           44.006257
# 1727         30           44.708055
# 1728         35           40.207289
# 1729         40           40.770813
# 1730         45           41.483008

# %%
lines = capomulin_df.plot(kind='line',x='Timepoint',y='Tumor Volume (mm3)', color='b')
#--Add x and y label and show graph
plt.title("Capomulin treatment of mouse |509")
plt.ylabel("Tumor Volume (mm3)")
plt.xlabel("Timepoint (days)")
plt.tight_layout()
plt.show()

# %%
final_tumor_max_timepoint = combined_data.groupby(["Mouse ID"]).max()
final_tumor = pd.merge(final_tumor_max_timepoint, combined_data, on  = 'Mouse ID')
final_tumor.head(20)
# box_plot_df= final_tumor.loc[(final_tumor['Timepoint_x']==final_tumor['Timepoint_y']),['Drug Regimen','Tumor Volume (mm3)_y']]
# box_plot_df
# # mouse_table = pd.merge(mouse_table,mouse_std, on = 'Drug Regimen')
# mouse_table.head()
# Out:
#    Mouse ID  Timepoint_x  Tumor Volume (mm3)_x  Metastatic Sites_x  \
# 0      a203           45             67.973419                   2
# 1      a203           45             67.973419                   2
# 2      a203           45             67.973419                   2
# 3      a203           45             67.973419                   2
# 4      a203           45             67.973419                   2
# 5      a203           45             67.973419                   2
# 6      a203           45             67.973419                   2
# 7      a203           45             67.973419                   2
# 8      a203           45             67.973419                   2
# 9      a203           45             67.973419                   2
# 10     a251           45             65.525743                   1
# 11     a251           45             65.525743                   1
# 12     a251           45             65.525743                   1
# 13     a251           45             65.525743                   1
# 14     a251           45             65.525743                   1
# 15     a251           45             65.525743                   1
# 16     a251           45             65.525743                   1
# 17     a251           45             65.525743                   1
# 18     a251           45             65.525743                   1
# 19     a251           45             65.525743                   1
#
#    Drug Regimen_x   Sex_x  Age_months_x  Weight (g)_x  Timepoint_y  \
# 0       Infubinol  Female            20            23            0
# 1       Infubinol  Female            20            23            5
# 2       Infubinol  Female            20            23           10
# 3       Infubinol  Female            20            23           15
# 4       Infubinol  Female            20            23           20
# 5       Infubinol  Female            20            23           25
# 6       Infubinol  Female            20            23           30
# 7       Infubinol  Female            20            23           35
# 8       Infubinol  Female            20            23           40
# 9       Infubinol  Female            20            23           45
# 10      Infubinol  Female            21            25            0
# 11      Infubinol  Female            21            25            5
# 12      Infubinol  Female            21            25           10
# 13      Infubinol  Female            21            25           15
# 14      Infubinol  Female            21            25           20
# 15      Infubinol  Female            21            25           25
# 16      Infubinol  Female            21            25           30
# 17      Infubinol  Female            21            25           35
# 18      Infubinol  Female            21            25           40
# 19      Infubinol  Female            21            25           45
#
#     Tumor Volume (mm3)_y  Metastatic Sites_y Drug Regimen_y   Sex_y  \
# 0              45.000000                   0      Infubinol  Female
# 1              48.508468                   0      Infubinol  Female
# 2              51.852437                   1      Infubinol  Female
# 3              52.777870                   1      Infubinol  Female
# 4              55.173336                   1      Infubinol  Female
# 5              56.793208                   1      Infubinol  Female
# 6              59.523197                   1      Infubinol  Female
# 7              61.931650                   2      Infubinol  Female
# 8              63.593490                   2      Infubinol  Female
# 9              67.973419                   2      Infubinol  Female
# 10             45.000000                   0      Infubinol  Female
# 11             46.982127                   0      Infubinol  Female
# 12             48.591179                   1      Infubinol  Female
# 13             50.534456                   1      Infubinol  Female
# 14             54.462594                   1      Infubinol  Female
# 15             57.414646                   1      Infubinol  Female
# 16             59.861241                   1      Infubinol  Female
# 17             60.903885                   1      Infubinol  Female
# 18             63.095076                   1      Infubinol  Female
# 19             65.525743                   1      Infubinol  Female
#
#     Age_months_y  Weight (g)_y
# 0             20            23
# 1             20            23
# 2             20            23
# 3             20            23
# 4             20            23
# 5             20            23
# 6             20            23
# 7             20            23
# 8             20            23
# 9             20            23
# 10            21            25
# 11            21            25
# 12            21            25
# 13            21            25
# 14            21            25
# 15            21            25
# 16            21            25
# 17            21            25
# 18            21            25
# 19            21            25

# %%
box_plot_df= final_tumor.loc[(final_tumor['Timepoint_x']==final_tumor['Timepoint_y']),['Drug Regimen_x',
                                                                                       'Tumor Volume (mm3)_y']]
box_plot_df.head()
# Out:
#    Drug Regimen_x  Tumor Volume (mm3)_y
# 9       Infubinol             67.973419
# 19      Infubinol             65.525743
# 29        Placebo             70.717621
# 39       Ceftamin             62.999356
# 46       Stelasyn             63.440686

# %%
Capomulin = box_plot_df.loc[box_plot_df['Drug Regimen_x']=='Capomulin','Tumor Volume (mm3)_y']
Capomulin
fig1, ax1 = plt.subplots()
ax1.boxplot(Capomulin)
plt.ylabel("Final Tumor Volume (mm3)")
plt.show()

# %%
Ramicane = box_plot_df.loc[box_plot_df['Drug Regimen_x']=='Ramicane','Tumor Volume (mm3)_y']
Ramicane
fig1, ax1 = plt.subplots()
ax1.boxplot(Ramicane)
plt.ylabel("Final Tumor Volume (mm3)")
plt.show()

# %%
Infubinol = box_plot_df.loc[box_plot_df['Drug Regimen_x']=='Infubinol','Tumor Volume (mm3)_y']
Infubinol
fig1, ax1 = plt.subplots()
ax1.boxplot(Infubinol)
plt.ylabel("Final Tumor Volume (mm3)")
plt.show()

# %%
Ceftamin = box_plot_df.loc[box_plot_df['Drug Regimen_x']=='Ceftamin','Tumor Volume (mm3)_y']
# Ceftamin
fig1, ax1 = plt.subplots()
ax1.boxplot(Infubinol)
plt.ylabel("Final Tumor Volume (mm3)")
plt.show()

# %%
data = Capomulin,Ramicane,Infubinol,Ceftamin
fig1, ax1 = plt.subplots()
ax1.boxplot(data)
plt.ylabel("Final Tumor Volume (mm3)")
plt.show()
